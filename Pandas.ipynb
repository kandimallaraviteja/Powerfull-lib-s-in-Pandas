# %% [markdown]
# # Importing lib

# %%
import pandas as pd

# %% [markdown]
# # 1. pd.read_csv()

# %% [markdown]
# ## pd.read_csv is a function in the panda's that is used to read a CSV file and convert it into a pandas DataFrame.

# %%
df = pd.read_csv('/home/msc2/Documents/2ed Sem/Subjects/datavizzz/Assignments/Assignment-1/accidents_2017.csv')

# %% [markdown]
# # 2. df.describe()

# %% [markdown]
# ## df.describe() gives the summary statistics of a DataFrame. Returns a new DataFrame that contains the count, mean, standard deviation, minimum, 25th percentile, median, 75th percentile, and maximum of each numerical column in the original DataFrame.

# %%
print(df.describe())
# Out:
#                 Day          Hour  Mild injuries  Serious injuries  \
# count  10339.000000  10339.000000   10339.000000      10339.000000
# mean      15.775994     13.811394       1.154174          0.023310
# std        8.763455      5.316490       0.742294          0.163803
# min        1.000000      0.000000       0.000000          0.000000
# 25%        8.000000     10.000000       1.000000          0.000000
# 50%       16.000000     14.000000       1.000000          0.000000
# 75%       23.000000     18.000000       1.000000          0.000000
# max       31.000000     23.000000      10.000000          4.000000
#
#             Victims  Vehicles involved     Longitude      Latitude
# count  10339.000000       10339.000000  10339.000000  10339.000000
# mean       1.178644           1.920979      2.162832     41.399346
# std        0.735145           0.714011      0.024176      0.021251
# min        0.000000           0.000000      2.091855     41.323094
# ...

# %%
df.describe(include='all')  # include all columns
# Out:
#                      Id District Name       Neighborhood Name  \
# count             10339         10339                   10339
# unique            10335            11                      74
# top     2017S008856          Eixample  la Dreta de l'Eixample
# freq                  2          3029                    1167
# mean                NaN           NaN                     NaN
# std                 NaN           NaN                     NaN
# min                 NaN           NaN                     NaN
# 25%                 NaN           NaN                     NaN
# 50%                 NaN           NaN                     NaN
# 75%                 NaN           NaN                     NaN
# max                 NaN           NaN                     NaN
#
#                                                    Street Weekday     Month  \
# count                                               10339   10339     10339
# ...

# %%
df.describe(exclude='number') # exclude numerical columns
# Out:
#                      Id District Name       Neighborhood Name  \
# count             10339         10339                   10339
# unique            10335            11                      74
# top     2017S008856          Eixample  la Dreta de l'Eixample
# freq                  2          3029                    1167
#
#                                                    Street Weekday     Month  \
# count                                               10339   10339     10339
# unique                                               4253       7        12
# top     Corts Catalanes                               ...  Friday  November
# freq                                                  219    1761       991
#
#        Part of the day
# count            10339
# unique               3
# top          Afternoon
# freq              5082

# %% [markdown]
# # 3. df.info()

# %% [markdown]
# ## df.info() is a method in pandas that is used to get a concise summary of the DataFrame

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10339 entries, 0 to 10338
# Data columns (total 15 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Id                 10339 non-null  object
#  1   District Name      10339 non-null  object
#  2   Neighborhood Name  10339 non-null  object
#  3   Street             10339 non-null  object
#  4   Weekday            10339 non-null  object
#  5   Month              10339 non-null  object
#  6   Day                10339 non-null  int64
#  7   Hour               10339 non-null  int64
#  8   Part of the day    10339 non-null  object
#  9   Mild injuries      10339 non-null  int64
#  10  Serious injuries   10339 non-null  int64
#  11  Victims            10339 non-null  int64
#  12  Vehicles involved  10339 non-null  int64
#  13  Longitude          10339 non-null  float64
#  14  Latitude           10339 non-null  float64
# dtypes: float64(2), int64(6), object(7)
# ...

# %% [markdown]
# # 4. df.plot()

# %%
df['Mild injuries'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
df['Vehicles involved'].value_counts().plot(kind='pie')
# Out:
# <AxesSubplot:ylabel='Vehicles involved'>

# %% [markdown]
# # 5. df.iloc()

# %%
df.iloc[0]
# Out:
# Id                                                     2017S008429
# District Name                                                  Unknown
# Neighborhood Name                                              Unknown
# Street               Número 27                                     ...
# Weekday                                                         Friday
# Month                                                          October
# Day                                                                 13
# Hour                                                                 8
# Part of the day                                                Morning
# Mild injuries                                                        2
# Serious injuries                                                     0
# Victims                                                              2
# Vehicles involved                                                    2
# ...

# %%
df.head()
# Out:
#                 Id District Name           Neighborhood Name  \
# 0  2017S008429           Unknown                     Unknown
# 1  2017S007316           Unknown                     Unknown
# 2  2017S010210           Unknown                     Unknown
# 3  2017S006364           Unknown                     Unknown
# 4  2017S004615        Sant Martí  el Camp de l'Arpa del Clot
#
#                                               Street   Weekday      Month  \
# 0  Número 27                                     ...    Friday    October
# 1  Número 3 Zona Franca / Número 50 Zona Franca  ...    Friday  September
# 2  Litoral (Besòs)                               ...    Friday   December
# 3  Número 3 Zona Franca                          ...    Friday       July
# 4  Las Navas de Tolosa                           ...  Thursday        May
#
#    Day  Hour Part of the day  Mild injuries  Serious injuries  Victims  \
# 0   13     8         Morning              2                 0        2
# ...

# %%
print(df.iloc[4, 0])
# Out:
# 2017S004615

# %%
print(df.iloc[:, :3])
# Out:
#                     Id District Name           Neighborhood Name
# 0      2017S008429           Unknown                     Unknown
# 1      2017S007316           Unknown                     Unknown
# 2      2017S010210           Unknown                     Unknown
# 3      2017S006364           Unknown                     Unknown
# 4      2017S004615        Sant Martí  el Camp de l'Arpa del Clot
# ...                ...           ...                         ...
# 10334  2017S003667       Sant Andreu               el Bon Pastor
# 10335  2017S001896       Sant Andreu               el Bon Pastor
# 10336  2017S010718       Sant Andreu               el Bon Pastor
# 10337  2017S006145       Sant Andreu               el Bon Pastor
# 10338  2017S000178       Sant Andreu               el Bon Pastor
#
# [10339 rows x 3 columns]

# %%
print(df.iloc[7, 4])
# Out:
# Tuesday

# %% [markdown]
# # 6. df.loc()

# %%
print(df.loc[:,'Hour'])
# Out:
# 0         8
# 1        13
# 2        21
# 3         2
# 4        14
#          ..
# 10334     8
# 10335    12
# 10336     8
# 10337    14
# 10338    20
# Name: Hour, Length: 10339, dtype: int64

# %% [markdown]
# # 7. df.assign()

# %% [markdown]
# ## Pandas’ .assign() function is used to add new columns to a DataFrame.

# %%
df_new = df.assign(count_plus_5=df['Victims'] + 5)
df_new.head()
# Out:
#                 Id District Name           Neighborhood Name  \
# 0  2017S008429           Unknown                     Unknown
# 1  2017S007316           Unknown                     Unknown
# 2  2017S010210           Unknown                     Unknown
# 3  2017S006364           Unknown                     Unknown
# 4  2017S004615        Sant Martí  el Camp de l'Arpa del Clot
#
#                                               Street   Weekday      Month  \
# 0  Número 27                                     ...    Friday    October
# 1  Número 3 Zona Franca / Número 50 Zona Franca  ...    Friday  September
# 2  Litoral (Besòs)                               ...    Friday   December
# 3  Número 3 Zona Franca                          ...    Friday       July
# 4  Las Navas de Tolosa                           ...  Thursday        May
#
#    Day  Hour Part of the day  Mild injuries  Serious injuries  Victims  \
# 0   13     8         Morning              2                 0        2
# ...

# %% [markdown]
# # 8. df.query()

# %% [markdown]
# ### Pandas’ .query() function allows you to filter a DataFrame based on a Boolean expression. It allows you to select rows from a DataFrame using a query string similar to SQL.

# %%
df_query = df.query('Hour > 3 and Victims > 3')
df_query.head()
# Out:
#                   Id District Name  \
# 2    2017S010210           Unknown
# 16   2017S002410        Sant Martí
# 64   2017S003914        Sant Martí
# 120  2017S003629        Sant Martí
# 155  2017S001333        Sant Martí
#
#                                 Neighborhood Name  \
# 2                                         Unknown
# 16                     el Camp de l'Arpa del Clot
# 64                          el Besòs i el Maresme
# 120                                   el Poblenou
# 155  Diagonal Mar i el Front Marítim del Poblenou
#
#                                                 Street    Weekday     Month  \
# 2    Litoral (Besòs)                               ...     Friday  December
# 16   CÒRSEGA / Dos de Maig                         ...   Saturday     March
# 64   Litoral (Llobregat)                           ...  Wednesday       May
# 120  Litoral (Besòs)                               ...     Sunday     April
# ...

# %%
df_query = df.query("Month	 == 'December'")
df_query.head()
# Out:
#                  Id District Name           Neighborhood Name  \
# 2   2017S010210           Unknown                     Unknown
# 7   2017S010680        Sant Martí  el Camp de l'Arpa del Clot
# 10  2017S010348        Sant Martí  el Camp de l'Arpa del Clot
# 18  2017S010102        Sant Martí  el Camp de l'Arpa del Clot
# 66  2017S010414        Sant Martí       el Besòs i el Maresme
#
#                                                Street   Weekday     Month  \
# 2   Litoral (Besòs)                               ...    Friday  December
# 7   Indústria                                     ...   Tuesday  December
# 10  Indústria                                     ...  Thursday  December
# 18  Rosselló / Independència                      ...    Monday  December
# 66  Eduard Maristany                              ...  Saturday  December
#
#     Day  Hour Part of the day  Mild injuries  Serious injuries  Victims  \
# ...

# %% [markdown]
# # 9. df.sort_values()

# %% [markdown]
# ### Pandas’ .sort_values() function allows you to sort a DataFrame by one or multiple columns. It sorts the DataFrame based on the values of one or more columns, in ascending or descending order.

# %%
df_sorted = df.sort_values(by='Weekday')
df_sorted.head()
# Out:
#                    Id District Name       Neighborhood Name  \
# 0     2017S008429           Unknown                 Unknown
# 4334  2017S003214          Eixample  la Dreta de l'Eixample
# 4337  2017S010010          Eixample  la Dreta de l'Eixample
# 4343  2017S006389          Eixample  la Dreta de l'Eixample
# 4352  2017S002393          Eixample  la Dreta de l'Eixample
#
#                                                  Street Weekday     Month  \
# 0     Número 27                                     ...  Friday   October
# 4334  Corts Catalanes                               ...  Friday     April
# 4337  Catalunya / Aragó                             ...  Friday  December
# 4343  Consell de Cent / Bailèn                      ...  Friday      July
# 4352  BALMES                                        ...  Friday     March
#
#       Day  Hour Part of the day  Mild injuries  Serious injuries  Victims  \
# 0      13     8         Morning              2                 0        2
# ...

# %%
df_sorted = df.sort_values(by='Mild injuries')
df_sorted.head()
# Out:
#                     Id        District Name  \
# 10338  2017S000178              Sant Andreu
# 3516   2017S008292                   Gràcia
# 10049  2017S004852      Sarrià-Sant Gervasi
# 8850   2017S001508           Horta-Guinardó
# 7420   2017S000894      Sarrià-Sant Gervasi
#
#                            Neighborhood Name  \
# 10338                          el Bon Pastor
# 3516               Vallcarca i els Penitents
# 10049  Vallvidrera, el Tibidabo i les Planes
# 8850                        el Baix Guinardó
# 7420                    el Putxet i el Farró
#
#                                                   Street   Weekday     Month  \
# 10338  CIUTAT D'ASUNCIÓN                             ...    Sunday   January
# 3516   Vallcarca                                     ...    Sunday   October
# 10049  Vallvidrera al Tibidabo                       ...    Friday      June
# 8850   RAMON ROCAFULL                                ...  Thursday  February
# ...

# %% [markdown]
# # 10. df.sample()

# %% [markdown]
# ### Pandas’ .sample() function allows you to randomly select rows from a DataFrame. It returns a new DataFrame containing the randomly selected rows.

# %%
df_sample = df.sample(n=5, replace=True, random_state=1)
df_sample
# Out:
#                    Id        District Name                  Neighborhood Name  \
# 235   2017S008482             Ciutat Vella                     la Barceloneta
# 5192  2017S006043               Sant Martí  el Parc i la Llacuna del Poblenou
# 905   2017S008769      Sarrià-Sant Gervasi                             Sarrià
# 7813  2017S007586               Sant Martí            Provençals del Poblenou
# 2895  2017S008647                 Eixample             la Dreta de l'Eixample
#
#                                                  Street    Weekday      Month  \
# 235   Pau Vila                                      ...     Sunday    October
# 5192  Corts Catalanes                               ...    Tuesday       July
# 905   Ramon Miquel i Planas                         ...     Monday    October
# 7813  Bac de Roda / Perú                            ...  Wednesday  September
# 2895  Roger de Llúria / Diagonal                    ...  Wednesday    October
#
# ...

# %% [markdown]
# # 11. df.isnull()

# %% [markdown]
# ### The isnull() method in Pandas returns a DataFrame of the same shape as the original DataFrame, but with True or False values indicating whether each value in the original DataFrame is missing or not. Missing values, such as NaN or None, will be True in the resulting DataFrame, while non-missing values will be False.

# %%
df.isnull()
# Out:
#           Id  District Name  Neighborhood Name  Street  Weekday  Month    Day  \
# 0      False          False              False   False    False  False  False
# 1      False          False              False   False    False  False  False
# 2      False          False              False   False    False  False  False
# 3      False          False              False   False    False  False  False
# 4      False          False              False   False    False  False  False
# ...      ...            ...                ...     ...      ...    ...    ...
# 10334  False          False              False   False    False  False  False
# 10335  False          False              False   False    False  False  False
# 10336  False          False              False   False    False  False  False
# 10337  False          False              False   False    False  False  False
# 10338  False          False              False   False    False  False  False
#
# ...

# %% [markdown]
# # 12. df.fillna()

# %% [markdown]
# ### The fillna() method in Pandas is used to fill in missing values in a DataFrame with a specified value or method. By default, it replaces missing values with NaN, but you can specify a different value to use instead as shown below:
#
# - value: Specifies the value to use to fill in the missing values. Can be a scalar value or a dict of values for different columns.
# - method: Specifies the method to use for filling in missing values. Can be 'ffill' (forward-fill) or 'bfill' (backward-fill) or 'interpolate'(interpolate values) or 'pad' or 'backfill'
# - axis: Specifies the axis along which to fill in missing values. It can be 0 (rows) or 1 (columns).
# - inplace: Whether to fill in the missing values in place (modifying the original DataFrame) or to return a new DataFrame with the missing values filled in.
# - limit: Specifies the maximum number of consecutive missing values to fill.
# - downcast: Specifies a dictionary of values to use to downcast the data types of columns.

# %%
df.fillna(0)  # fill missing values with 0
df.fillna(method='ffill')# forward-fill missing values (propagates last valid observation forward to next)
df.fillna(method='bfill')# backward-fill missing values (propagates next valid observation backward to last)
df.interpolate()# fill missing values using interpolation
# Out:
#                     Id District Name           Neighborhood Name  \
# 0      2017S008429           Unknown                     Unknown
# 1      2017S007316           Unknown                     Unknown
# 2      2017S010210           Unknown                     Unknown
# 3      2017S006364           Unknown                     Unknown
# 4      2017S004615        Sant Martí  el Camp de l'Arpa del Clot
# ...                ...           ...                         ...
# 10334  2017S003667       Sant Andreu               el Bon Pastor
# 10335  2017S001896       Sant Andreu               el Bon Pastor
# 10336  2017S010718       Sant Andreu               el Bon Pastor
# 10337  2017S006145       Sant Andreu               el Bon Pastor
# 10338  2017S000178       Sant Andreu               el Bon Pastor
#
#                                                   Street    Weekday  \
# 0      Número 27                                     ...     Friday
# ...

# %% [markdown]
# # 13. df.dropna()

# %% [markdown]
# ### df.dropna() is a method used in the Pandas library to remove missing or null values from a DataFrame. It removes rows or columns from the DataFrame where at least one element is missing.

# %%
df = df.dropna()

# %% [markdown]
# # 14. df.drop()

# %% [markdown]
# ### df.drop() is a method used in the Pandas library to remove rows or columns from a DataFrame by specifying the corresponding labels.

# %%
df_drop = df.drop(0) # Removes the first row of the data frame
df_drop = df.drop([0,1]) # Drops the multiple rows from the data frame
df_drop = df.drop(['Hour', 'Weekday'], axis=1) # dropping the columns by name the column names

# %% [markdown]
# # 15. pd.pivot_table()

# %% [markdown]
# ### pd.pivot_table() is a method in the Pandas library that is used to create a pivot table from a DataFrame. A pivot table is a table that summarizes and aggregates data in a more meaningful and organized way.

# %%
pivot_table = pd.pivot_table(df, index='Id', values='Victims', aggfunc='sum')
pivot_table.head()
# Out:
#                  Victims
# Id
# 2017S000001            1
# 2017S000002            1
# 2017S000003            0
# 2017S000004            1
# 2017S000005            2

# %%
pivot_tables = pd.pivot_table(df, index = 'Month', values = 'Mild injuries', aggfunc = 'sum' )
pivot_tables.head()
# Out:
#           Mild injuries
# Month
# April               912
# August              793
# December            883
# February            925
# January             975

# %% [markdown]
# # 16. df.groupby()

# %% [markdown]
# ### df.groupby() is a method in the Pandas library that is used to group rows of a DataFrame based on one or multiple columns. This allows us to perform aggregate operations on the groups, such as calculating the
# - mean
# - sum or count of the values in each group.

# %%
grouped = df.groupby('Victims')
print(grouped.mean())
# Out:
#                Day       Hour  Mild injuries  Serious injuries  \
# Victims
# 0        15.002217  12.491131       0.000000          0.000000
# 1        15.895193  13.905349       0.977116          0.021666
# 2        15.728119  14.175667       1.964618          0.034140
# 3        15.394366  13.707746       2.947183          0.049296
# 4        15.970588  13.254902       3.931373          0.068627
# 5        15.062500  12.718750       4.968750          0.031250
# 6        17.090909  14.181818       6.000000          0.000000
# 7        13.125000  15.750000       6.500000          0.500000
# 8        19.000000  13.000000       8.000000          0.000000
# 9        16.000000  20.000000       9.000000          0.000000
# 10       20.500000  17.000000      10.000000          0.000000
#
#          Vehicles involved  Longitude   Latitude
# Victims
# 0                 1.804878   2.164254  41.401539
# 1                 1.885985   2.162440  41.398717
# ...

# %% [markdown]
# # 17. df.transpose()

# %% [markdown]
# ### df.transpose() is a method in the Pandas library used to transpose the rows and columns of a DataFrame? This means that the rows become columns and the columns become rows.

# %%
df.head()
# Out:
#                 Id District Name           Neighborhood Name  \
# 0  2017S008429           Unknown                     Unknown
# 1  2017S007316           Unknown                     Unknown
# 2  2017S010210           Unknown                     Unknown
# 3  2017S006364           Unknown                     Unknown
# 4  2017S004615        Sant Martí  el Camp de l'Arpa del Clot
#
#                                               Street   Weekday      Month  \
# 0  Número 27                                     ...    Friday    October
# 1  Número 3 Zona Franca / Número 50 Zona Franca  ...    Friday  September
# 2  Litoral (Besòs)                               ...    Friday   December
# 3  Número 3 Zona Franca                          ...    Friday       July
# 4  Las Navas de Tolosa                           ...  Thursday        May
#
#    Day  Hour Part of the day  Mild injuries  Serious injuries  Victims  \
# 0   13     8         Morning              2                 0        2
# ...

# %%
df_transposed = df.transpose()
df_transposed.head()
# Out:
#                                                                0      \
# Id                                                   2017S008429
# District Name                                                Unknown
# Neighborhood Name                                            Unknown
# Street             Número 27                                     ...
# Weekday                                                       Friday
#
#                                                                1      \
# Id                                                   2017S007316
# District Name                                                Unknown
# Neighborhood Name                                            Unknown
# Street             Número 3 Zona Franca / Número 50 Zona Franca  ...
# Weekday                                                       Friday
#
#                                                                2      \
# Id                                                   2017S010210
# ...

# %% [markdown]
# # 18. df.merge()

# %% [markdown]
# ### df.merge() is a pandas function that allows you to combine two DataFrames based on one or more common columns. It is similar to SQL JOINs.

# %%
df1 = pd.DataFrame({'key': ['A', 'B', 'C', 'D'],'value': [1, 2, 3, 4]})
df2 = pd.DataFrame({'key': ['B', 'D', 'E', 'F'],'value': [5, 6, 7, 8]})
merged_df = df1.merge(df2, on='key')
print(df1)
print(df2)
print(merged_df)
# Out:
#   key  value
# 0   A      1
# 1   B      2
# 2   C      3
# 3   D      4
#   key  value
# 0   B      5
# 1   D      6
# 2   E      7
# 3   F      8
#   key  value_x  value_y
# 0   B        2        5
# 1   D        4        6

# %% [markdown]
# # 19. df.rename()

# %% [markdown]
# ### df.rename() is a pandas function that allows you to change the name of one or more columns or rows in a DataFrame

# %%
# Rename column 'Count' to 'count'
df_rename = df.rename(columns={'Weekday': 'Day'})
df_rename.head()
# Out:
#                 Id District Name           Neighborhood Name  \
# 0  2017S008429           Unknown                     Unknown
# 1  2017S007316           Unknown                     Unknown
# 2  2017S010210           Unknown                     Unknown
# 3  2017S006364           Unknown                     Unknown
# 4  2017S004615        Sant Martí  el Camp de l'Arpa del Clot
#
#                                               Street       Day      Month  \
# 0  Número 27                                     ...    Friday    October
# 1  Número 3 Zona Franca / Número 50 Zona Franca  ...    Friday  September
# 2  Litoral (Besòs)                               ...    Friday   December
# 3  Número 3 Zona Franca                          ...    Friday       July
# 4  Las Navas de Tolosa                           ...  Thursday        May
#
#    Day  Hour Part of the day  Mild injuries  Serious injuries  Victims  \
# 0   13     8         Morning              2                 0        2
# ...

# %% [markdown]
# # 20. df.to_csv()

# %% [markdown]
# ### df.to_csv() is a method used in the Pandas library to export a DataFrame to a CSV file.

# %%
path = "/home/msc2/Desktop/"
df.to_csv(path + 'data.csv')
